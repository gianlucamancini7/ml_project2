# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
DATA_FOLDER = './2018-11-14_Mesures_MoTUS'

# %%
temp_mast = pd.read_csv(DATA_FOLDER+'/141118TempMat.txt', sep=",", header=None, error_bad_lines=False)
temp_north = pd.read_csv(DATA_FOLDER+'/141118TempNorth.txt', sep=",", header=None, error_bad_lines=False)
temp_south = pd.read_csv(DATA_FOLDER+'/141118TempSouth.txt', sep=",", header=None, error_bad_lines=False)
anemometer_7 = pd.read_csv(DATA_FOLDER+'/141118anem7_20Hz.txt', sep=",", header=None, error_bad_lines=False)
anemometer_6 = pd.read_csv(DATA_FOLDER+'/141118anem6_20Hz.txt', sep=",", header=None, error_bad_lines=False)
anemometer_5 = pd.read_csv(DATA_FOLDER+'/141118anem5_20Hz.txt', sep=",", header=None, error_bad_lines=False)
anemometer_4 = pd.read_csv(DATA_FOLDER+'/141118anem4_20Hz.txt', sep=",", header=None, error_bad_lines=False)
anemometer_3 = pd.read_csv(DATA_FOLDER+'/141118anem2_20Hz.txt', sep=",", header=None, error_bad_lines=False)
anemometer_2 = pd.read_csv(DATA_FOLDER+'/141118anem2_20Hz.txt', sep=",", header=None, error_bad_lines=False)
anemometer_1 = pd.read_csv(DATA_FOLDER+'/141118anem1_20Hz.txt', sep=",", header=None, error_bad_lines=False)
# Out:
# b'Skipping line 312620: expected 9 fields, saw 10\nSkipping line 312675: expected 9 fields, saw 10\nSkipping line 315265: expected 9 fields, saw 10\nSkipping line 315266: expected 9 fields, saw 10\nSkipping line 315347: expected 9 fields, saw 10\n'
# b'Skipping line 507891: expected 9 fields, saw 10\nSkipping line 510261: expected 9 fields, saw 10\nSkipping line 510281: expected 9 fields, saw 10\nSkipping line 510283: expected 9 fields, saw 10\nSkipping line 512083: expected 9 fields, saw 10\n'
# b'Skipping line 545193: expected 9 fields, saw 10\nSkipping line 552659: expected 9 fields, saw 10\nSkipping line 552660: expected 9 fields, saw 10\nSkipping line 552661: expected 9 fields, saw 10\nSkipping line 552662: expected 9 fields, saw 10\nSkipping line 552663: expected 9 fields, saw 10\nSkipping line 552665: expected 9 fields, saw 10\n'
# b'Skipping line 692032: expected 9 fields, saw 10\n'
# ...

# %%
avg_7=anemometer_7.iloc[:,2].mean()
avg_6=anemometer_6.iloc[:,2].mean()
avg_5=anemometer_5.iloc[:,2].mean()
avg_4=anemometer_4.iloc[:,2].mean()
avg_3=anemometer_3.iloc[:,2].mean()
avg_2=anemometer_2.iloc[:,2].mean()
avg_1=anemometer_1.iloc[:,2].mean()

# %%
speeds=[avg_7,avg_6,avg_5,avg_4,avg_3,avg_2,avg_1]
h=[27,23,19,15,11,7,3]
speeds
# Out:
# [2.1067559496941786,
#  1.9458008942912117,
#  1.7931676936302667,
#  1.4884831988617095,
#  0.576189601381823,
#  0.576189601381823,
#  0.4973692562575532]

# %%
plt.scatter(h,speeds)

# %%
anemometer_7.iloc[:,6].plot()

# %%
temp_mast.iloc[:,0].plot()

# %%
temp_north.iloc[:,0].plot()

# %%
temp_south.iloc[:,0].plot()
