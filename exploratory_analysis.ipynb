# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
path='./data_trial/'

# %%
os.listdir(path)
# Out:
# ['.DS_Store', '2018-11-14_Mesures_MoTUS']

# %%
anemometer_7=pd.read_table(path+'2018-11-14_Mesures_MoTUS/141118anem7_20Hz.txt', header=None, delimiter=',', error_bad_lines=False)
# Out:
# b'Skipping line 312620: expected 9 fields, saw 10\nSkipping line 312675: expected 9 fields, saw 10\nSkipping line 315265: expected 9 fields, saw 10\nSkipping line 315266: expected 9 fields, saw 10\nSkipping line 315347: expected 9 fields, saw 10\n'
# b'Skipping line 507891: expected 9 fields, saw 10\nSkipping line 510261: expected 9 fields, saw 10\nSkipping line 510281: expected 9 fields, saw 10\nSkipping line 510283: expected 9 fields, saw 10\nSkipping line 512083: expected 9 fields, saw 10\n'
# b'Skipping line 545193: expected 9 fields, saw 10\nSkipping line 552659: expected 9 fields, saw 10\nSkipping line 552660: expected 9 fields, saw 10\nSkipping line 552661: expected 9 fields, saw 10\nSkipping line 552662: expected 9 fields, saw 10\nSkipping line 552663: expected 9 fields, saw 10\nSkipping line 552665: expected 9 fields, saw 10\n'
# b'Skipping line 692032: expected 9 fields, saw 10\n'
# ...

# %%
anemometer_7.head()
# Out:
#     0    1     2     3  4       5      6                    7      8
# 0  Q  292  2.91  0.40  M  339.74  13.41  14.11.2018 00:00:00  COM17
# 1  Q  293  2.98  0.42  M  339.75  13.42  14.11.2018 00:00:00  COM17
# 2  Q  298  2.98  0.52  M  339.72  13.37  14.11.2018 00:00:00  COM17
# 3  Q  297  3.09  0.47  M  339.74  13.41  14.11.2018 00:00:00  COM17
# 4  Q  295  3.07  0.41  M  339.77  13.46  14.11.2018 00:00:00  COM17

# %%
anemometer_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727988 entries, 0 to 1727987
# Data columns (total 9 columns):
# 0    object
# 1    int64
# 2    float64
# 3    float64
# 4    object
# 5    float64
# 6    float64
# 7    object
# 8    object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 118.7+ MB

# %%
anemometer_1.iloc[:6000,1].plot()

# %%
v=(anemometer_1.iloc[:,1].^2+anemometer_1.iloc[:,2]^2, anemometer_1.iloc[:,3]^2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1273         try:
# -> 1274             result = op(x, y)
#    1275         except TypeError:
#
# TypeError: ufunc 'bitwise_xor' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1290                 try:
# -> 1291                     result = libops.scalar_binop(x, y, op)
#    1292                 except:
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_binop()
#
# ...
