# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
path='./data_trial/'

# %%
os.listdir(path)
# Out:
# ['.DS_Store', '2018-11-14_Mesures_MoTUS']

# %%
anemometer_7=pd.read_table(path+'2018-11-14_Mesures_MoTUS/141118anem7_20Hz.txt', header=None, delimiter=',', error_bad_lines=False)
# Out:
# b'Skipping line 312620: expected 9 fields, saw 10\nSkipping line 312675: expected 9 fields, saw 10\nSkipping line 315265: expected 9 fields, saw 10\nSkipping line 315266: expected 9 fields, saw 10\nSkipping line 315347: expected 9 fields, saw 10\n'
# b'Skipping line 507891: expected 9 fields, saw 10\nSkipping line 510261: expected 9 fields, saw 10\nSkipping line 510281: expected 9 fields, saw 10\nSkipping line 510283: expected 9 fields, saw 10\nSkipping line 512083: expected 9 fields, saw 10\n'
# b'Skipping line 545193: expected 9 fields, saw 10\nSkipping line 552659: expected 9 fields, saw 10\nSkipping line 552660: expected 9 fields, saw 10\nSkipping line 552661: expected 9 fields, saw 10\nSkipping line 552662: expected 9 fields, saw 10\nSkipping line 552663: expected 9 fields, saw 10\nSkipping line 552665: expected 9 fields, saw 10\n'
# b'Skipping line 692032: expected 9 fields, saw 10\n'
# ...

# %%
anemometer_7.head()
# Out:
#     0    1     2     3  4       5      6                    7      8
# 0  Q  292  2.91  0.40  M  339.74  13.41  14.11.2018 00:00:00  COM17
# 1  Q  293  2.98  0.42  M  339.75  13.42  14.11.2018 00:00:00  COM17
# 2  Q  298  2.98  0.52  M  339.72  13.37  14.11.2018 00:00:00  COM17
# 3  Q  297  3.09  0.47  M  339.74  13.41  14.11.2018 00:00:00  COM17
# 4  Q  295  3.07  0.41  M  339.77  13.46  14.11.2018 00:00:00  COM17

# %%
radiometer=pd.read_table(path+'2018-11-14_Mesures_MoTUS/141118radiometre.txt', header=None, delimiter=',', error_bad_lines=False)

# %%
anemometer_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1727988 entries, 0 to 1727987
# Data columns (total 9 columns):
# 0    object
# 1    int64
# 2    float64
# 3    float64
# 4    object
# 5    float64
# 6    float64
# 7    object
# 8    object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 118.7+ MB

# %%
anemometer_1.iloc[:6000,1].plot()

# %%
radiometer.head()
# Out:
#          0         1           2           3         4          5          6   \
# 0  8.447903  1.640495  380.877971  364.936434  0.194190   6.807408  22.748945
# 1 -3.942355 -4.374653  373.363103  374.662193  1.109655   0.432298  -0.866792
# 2  3.942355 -6.561980  366.490855  361.318352 -1.664482  10.504334  15.676838
# 3  1.126387 -6.015148  356.748099  363.178280 -5.340214   7.141535   0.711354
# 4 -0.563194 -1.093663  367.698350  360.879253  1.941896   0.530470   7.349567
#
#           7          8          9      10                   11
# 0  15.941537  13.136388  10.092580  10.58  14.11.2018 00:00:04
# 1  -1.299090  11.713683  11.961151  10.61  14.11.2018 00:00:09
# 2   5.172503  10.393712   9.387918  10.27  14.11.2018 00:00:14
# 3  -6.430181   8.490205   9.750817  10.24  14.11.2018 00:00:19
# 4   6.819098  10.626975   9.302039  10.38  14.11.2018 00:00:24

# %%
fig=plt.figure(figsize=(15,15))
plt.subplot(331)
radiometer.iloc[:,0].plot()
plt.subplot(332)
radiometer.iloc[:,1].plot()
plt.subplot(333)
radiometer.iloc[:,2].plot()
plt.subplot(334)
radiometer.iloc[:,3].plot()
plt.subplot(335)
radiometer.iloc[:,4].plot()
plt.subplot(336)
radiometer.iloc[:,5].plot()
plt.subplot(337)
radiometer.iloc[:,6].plot()
plt.subplot(338)
radiometer.iloc[:,7].plot()
plt.subplot(339)
radiometer.iloc[:,8].plot()

# %%
fig=plt.figure(figsize=(15,15))
plt.subplot(121)
radiometer.iloc[:,9].plot()
plt.subplot(122)
radiometer.iloc[:,10].plot()
