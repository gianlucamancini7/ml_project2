# %%
import matplotlib.pyplot as plt
import numpy as np
from helpers import plot_height_average
from helpers import plot_method_comparasion
from helpers import load_comparable_reault

# %%
import pandas as pd 
INPUT_FOLDER = '../results/'
OUTPUT_FOLDER = '../results/results_analysis/'

# %% [markdown]
# ## The regression methods that you want to compare

# %%
methods = ['baseline','ridge_regression','neural_network','random_forest']

# %% [markdown]
# ## Create the compact matrix of the performance evaluation

# %%
u_true,u_compact,u_std,mse_compact,rsq_compact = load_comparable_reault(INPUT_FOLDER,methods)

# %% [markdown]
# ## Compare the season-wise average speed for each anemometer

# %%
plot_height_average(u_compact, u_true, u_std, mse_compact, methods, path = OUTPUT_FOLDER, save=True)

# %% [markdown]
# ## Compare the season-wise mse of each methods in evaluation of anemometers

# %%
plot_method_comparasion(mse_compact, methods, ylabel = 'mse',path = OUTPUT_FOLDER, name = 'compare_mse', save = True)

# %% [markdown]
# ## Compare the season-wise $R^2$ of each methods in evaluation of anemometers

# %%
plot_method_comparasion(rsq_compact, methods, ylabel = '$R^2$',path = OUTPUT_FOLDER, name = 'compare_rsq', save = True)
